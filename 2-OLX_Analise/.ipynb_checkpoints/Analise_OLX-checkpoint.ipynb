# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
# %matplotlib inline

# %% [markdown]
# O que este notebook ira realizar:
# ---------------------------------
#
# 1. Analise dos resultados dos notebooks anteriores retirados do site da OLX
# 2. Selecionar apenas os anuncios de Casas
# 3. Agrupar os registros pelo bairro com a soma e media dos preços
# 4. Mostrar os dez maiores valores do agrupamento em grafico usando a biblioteca **Matplotlib**

# %%
df = pd.read_excel('../1-OLX_WebScrap/1_OLX_CASA_SEM_CEP.xlsx')

# %%
df.head()
# Out:
#   categoria                                         titulo   preco  \
# 0     Casas  Você busca um região privilegiada para morar?  850000
# 1     Casas                Alugo Quarto Cozinha e Banheiro     550
# 2     Casas               Lindo Sobrado Fotos por WhatsApp  700000
# 3     Casas                                           Casa    1500
# 4     Casas      Casa no Tucuruvi, 3 quartos sendo 1 suíte  700000
#
#                                                 href   zona  profissional  \
# 0  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  Norte         False
# 1  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  Norte         False
# 2  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  Norte         False
# 3  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  Norte          True
# 4  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  Norte         False
#
#                       bairro
# 0   Jardim São Paulo - Norte
# 1                 Vila Guaca
# 2                Vila Mazzei
# 3                Vila Mazzei
# 4             Parada Inglesa

# %%
df = df[['bairro', 'categoria', 'preco']]

# %%
df.loc[:,['categoria']] = df['categoria'].astype('category')
df.loc[:,['preco']] = df['preco'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4498 entries, 0 to 4497
# Data columns (total 3 columns):
# bairro       4498 non-null object
# categoria    4498 non-null category
# preco        4498 non-null float64
# dtypes: category(1), float64(1), object(1)
# memory usage: 109.9+ KB

# %%
df.groupby(['categoria'])['preco'].count()
# Out:
# categoria
# Casas    4498
# Name: preco, dtype: int64

# %%
df.categoria.unique()
# Out:
# [Casas]
# Categories (1, object): [Casas]

# %%
#seleciona apenas a coluna bairro e preço
df = df[['bairro', 'preco']]

# %%
#cria um data frame com a soma dos precos dos bairros
df_soma = df.groupby(['bairro'], as_index=False)['preco'].sum()
#ordena o DataFrame pelo preco descendente
df_soma = df_soma.sort_values(by='preco',ascending=False)
#Reseta o index do DataFrame
df_soma = df_soma.reset_index(drop='index')

# %%
df_soma
# Out:
#                               bairro       preco
# 0                     Jardim América  76235000.0
# 1                  Alto De Pinheiros  63060390.0
# 2                           Tucuruvi  57502350.0
# 3                           Tremembé  56092449.0
# 4                      Jardim Europa  54700000.0
# 5                            Vila Ré  53240550.0
# 6                            Santana  52205338.0
# 7                    Jardim Paulista  47840000.0
# 8                       Jardim Russo  47113650.0
# 9                     Vila Albertina  38142000.0
# 10                     Vila Madalena  37321300.0
# 11                     Jardim Franca  37215050.0
# 12          Jardim São Paulo - Norte  35240299.0
# 13                       Vila Mazzei  33156429.0
# 14                   Santa Teresinha  31528100.0
# 15                        Belenzinho  29859856.0
# 16                         Água Fria  29581100.0
# 17                    Jardim Guedala  28610000.0
# 18                     Cidade Jardim  28400000.0
# 19                  Vila Nova Mazzei  28109675.0
# 20                         Aclimação  27825300.0
# 21                             Mooca  27510550.0
# 22                          Pacaembu  27251000.0
# 23    Jardim Leonor Mendes De Barros  24727000.0
# 24                  Jardim São Bento  24710000.0
# 25            Jardim Virginia Bianca  24056940.0
# 26                           Cambuci  22562400.0
# 27                 Jardim Paulistano  22506651.0
# 28                   Horto Florestal  22254000.0
# 29                Vila Irmãos Arnoni  21656800.0
# ..                               ...         ...
# 907                   Jardim Humaitá       650.0
# 908                  Vila Paulista I       600.0
# 909                   Jardim Cambara       600.0
# 910                 Parque Esperança       600.0
# 911                  Jardim Novo Jaú       600.0
# 912                     Vila Jussara       600.0
# 913                   Jardim Cláudia       600.0
# 914             Parque Dos Bancários       600.0
# 915                         Guaiaúna       590.0
# 916                    Parque Grajaú       590.0
# 917                  Parque São José       550.0
# 918                      Vila Sulina       550.0
# 919                 Vila Santa Lúcia       550.0
# 920                 Cj Hab Turística       550.0
# 921            Jardim Nova Vitória I       550.0
# 922                 Vila Nova Teresa       550.0
# 923                    Vila Fazzeoni       500.0
# 924                      Vila Caiúba       500.0
# 925          Balneário São Francisco       500.0
# 926            Jardim Haia do Carrão       500.0
# 927                    Jardim Noemia       470.0
# 928                 Jardim Macedônia       460.0
# 929                     Jardim Tanay       450.0
# 930                   Jardim Andaraí       400.0
# 931                   Vila Aparecida       400.0
# 932                Cj Hab I Monteiro       250.0
# 933                 Estância Tangara       150.0
# 934                   Jardim Vitória       110.0
# 935               Jardim Laranjeiras       110.0
# 936                      Jardim Nair        30.0
#
# [937 rows x 2 columns]

# %%
#cria um data frame com a media dos precos dos bairros
df_media = df.groupby(['bairro'], as_index=False)['preco'].mean()
#ordena o DataFrame pela media de preco descendente
df_media = df_media.sort_values(by='preco',ascending=False)
#Reseta o index do DataFrame
df_media = df_media.reset_index(drop='index')

# %%
#Seleciona os dez primeiros bairros da soma de preços
df_soma_dez=df_soma.head(10)

# %%
#Seleciona os dez primeiros bairros da media de preços
df_media_dez=df_media.head(10)

# %%
#Graficos da soma e media dos dez bairros mais caros, respectivamente
df_soma_dez.plot.bar(x=df_soma_dez['bairro'],title='Soma dos Dez Primeiros')

df_media_dez.plot.bar(x=df_media_dez['bairro'],title='Media dos Dez Primeiros')
