# %%
import pandas as pd
import requests
import googlemaps
import folium
from folium import plugins

# %%
df = pd.read_excel('lat_lng.xlsx')
lat_lng_dict = {}

# %%
df.head()
# Out:
#             municipio                                 estado  \
# 0          Belenzinho          ('São Paulo', 'Apartamentos')
# 1          Belenzinho          ('São Paulo', 'Apartamentos')
# 2               Mooca          ('São Paulo', 'Apartamentos')
# 3       Vila Bertioga                 ('São Paulo', 'Casas')
# 4  Vila Independência  ('São Paulo', 'Indústria e comércio')
#
#               categoria                                             titulo  \
# 0          Apartamentos  Camino Belem (ZL1244) Desocupado || Lazer Comp...
# 1          Apartamentos  Rossi Lumina (ZL1243) Mobiliado || Lazer Completo
# 2          Apartamentos  Apartamento mooca totalmente reformado ótima l...
# 3                 Casas  Sobrado Vila Bertioga,3 dormitorios 1 suite 3 ...
# 4  Indústria e comércio                                Loja física de AÇAÍ
#
#     preco                                               href        cep
# 0  660000  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  03058-000
# 1  850000  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  03059-005
# 2    2000  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  03121-020
# 3    4000  http://sp.olx.com.br/sao-paulo-e-regiao/imovei...  03181-010
# 4   35000  http://sp.olx.com.br/sao-paulo-e-regiao/indust...  04222-000

# %%
gmaps = googlemaps.Client(key='AIzaSyDsIbQzmDewD3hyoDjXs7Tw81HeWcL3l3M')

# %%
arr = df.municipio.unique()

# %%
for municipio in arr:
    geocode_result = gmaps.geocode(str(municipio)+', São Paulo')
    lat_lng_dict.update({municipio: [geocode_result[0]['geometry']['location']['lat'], geocode_result[0]['geometry']['location']['lng']]})

# %%
df['lat_lng'] = df['municipio'].map(lat_lng_dict)

# %%
df[['lat','lng']] = pd.DataFrame(df.lat_lng.values.tolist(), index= df.index)

# %%
df.drop(labels='lat_lng',axis=1, inplace=True)

# %%
df.to_excel('lat_lng.xlsx')

# %%
df2 = df[['lat','lng']].values.tolist()

# %%
m = folium.Map(list(df2[0]), zoom_start=10)

# %%
m.add_child(plugins.HeatMap(df2, radius=10))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fn='testmap.html'

# %%
m.save(fn)
