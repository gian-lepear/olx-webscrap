# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests

# %%
# r = requests.get('http://www.olx.com.br/imoveis?o=1&sp=1')

# %%
# soup = BeautifulSoup(r.content, 'html.parser')

# %%
# li_list = []
# for ultag in soup.find_all('ul', {'class': 'list', 'id':'main-ad-list' }):
#     for litag in ultag.find_all(lambda tag: tag.name == 'li' and tag.get('class') == ['item']):
#         li_list.append(litag)

# %%
# x = BeautifulSoup(str(li_list[0]), 'html.parser')

# %%
#info = x.find('div', {'class':'col-2'})
#cidade_estado = info.find('div', {'class':'OLXad-list-line-2'}).find('p', {'class':'text detail-region'}).text.replace('\n','').replace('\t','')
#categoria = info.find('div', {'class':'OLXad-list-line-2'}).find('p', {'class':'text detail-category'}).text.replace('\n','').replace('\t','')
#titulo = info.find('div', {'class':'OLXad-list-line-1 mb5px'}).find('h3', {'class':'OLXad-list-title mb5px'}).text.replace('\n','').replace('\t','')
#preco = x.find('div', {'class':'col-3'}).find('p', {'class':'OLXad-list-price'}).text.replace('\t','').replace('R$', '')

# %%
#comando1 = encontraValores('titulo','info',['div','h3'], ['OLXad-list-line-1 mb5px','OLXad-list-title mb5px'])

# %%
#caomando2 = encontraValores('info_preco','x', 'div', 'col-3')

# %%
#usando a função para pegar os valores :D
#info -> html com as listas de casas
#cidade_estado -> local
#categoria -> categoria que esta no site
#titulo -> titulo que esta no site
#preco -> preco no site do imovel

# %%
#comando1 = encontraValores('info','x', 'div', 'col-2')
#comando2 = encontraValores('cidade_estado', 'info', ['div', 'p'], ['OLXad-list-line-2','text detail-region'], True)
#comando3 = encontraValores('categoria', 'info', ['div', 'p'], ['OLXad-list-line-2','text detail-category'], True)
#comando4 = encontraValores('titulo','info',['div','h3'], ['OLXad-list-line-1 mb5px','OLXad-list-title mb5px'], True)
#comando5 = encontraValores('preco','x',['div','p'], ['col-3','OLXad-list-price'], True)

# %%
#exec(comando1)
#exec(comando2)
#exec(comando3)
#exec(comando4)
#exec(comando5)

# %%
#df = pd.DataFrame.from_dict([dict(zip(labels, valores))])

# %%
#rodar todo o bagulho doido
#botar tudo em uma lista/dict
#tacar num dataframe
#ser feliz

# %%
labels = ['municipio','estado', 'categoria', 'titulo', 'preco']
valores= []
def  encontraValores(variavel, html, tag, classe, texto=False):
    retiraEspecial = ".text.replace('\\n','').replace('\\t','').replace('R$ ', '')"
    if type(tag) == list and type(classe) == list:
        if len(tag) != len(classe):
            return 'classe e tag precisam ter o mesmo numero de elementos'
        else:
            x = ''.join('.find(\''+ tg +'\', {\'class\':\''+ cl +'\'})' for cl, tg in zip(classe, tag))
    else:
        x = ''.join('.find(\''+ tag +'\', {\'class\':\''+ classe +'\'})')
    comando = variavel + "=" +html+ x + retiraEspecial if texto else variavel + "=" +html+ x
    return comando

# %%
for iter in range(100):
    r = requests.get('http://www.olx.com.br/imoveis?o='+str(iter)+'&sp=1')
    soup = BeautifulSoup(r.content, 'html.parser')
    
    for ultag in soup.find_all('ul', {'class': 'list', 'id':'main-ad-list' }):
        for litag in ultag.find_all(lambda tag: tag.name == 'li' and tag.get('class') == ['item']):
            li_list.append(litag)

    for elements in li_list:
        x = BeautifulSoup(str(elements), 'html.parser')
        #cria os comandos
        comando1 = encontraValores('info','x', 'div', 'col-2')
        comando2 = encontraValores('cidade_estado', 'info', ['div', 'p'], ['OLXad-list-line-2','text detail-region'], True)
        comando3 = encontraValores('categoria', 'info', ['div', 'p'], ['OLXad-list-line-2','text detail-category'], True)
        comando4 = encontraValores('titulo','info',['div','h3'], ['OLXad-list-line-1 mb5px','OLXad-list-title mb5px'], True)
        comando5 = encontraValores('preco','x',['div','p'], ['col-3','OLXad-list-price'], True)
        #roda os comandos
        exec(comando1)
        exec(comando2)
        exec(comando3)
        exec(comando4)
        exec(comando5)
        valores.append([cidade_estado[:-5],cidade_estado[-2:],categoria,titulo,float(preco)])

# %%
# for elements in li_list:
#     elements.parent.find('li', {'class':'item list_native'}).decompose()

# %%
# soup.find_all(lambda tag: tag.name == 'li' and tag.get('class') == ['item'])

# %%
df = pd.DataFrame(valores, columns=labels)

# %%
df['preco'] = df['preco'].astype(float)

# %%
df['categoria'] = df['categoria'].astype('category')

# %%
df
# Out:
#                      municipio estado  \
# 0                      Garuva      SC
# 1                Porto Seguro      BA
# 2                    São Luís      MA
# 3                    Santarém      PA
# 4                     Aracaju      SE
# 5               Florianópolis      SC
# 6                         Jaú      SP
# 7                    Araruama      RJ
# 8                   Araucária      PR
# 9                       Belém      PA
# 10                      Betim      MG
# 11                  Fortaleza      CE
# 12                  Guarulhos      SP
# 13                      Natal      RN
# 14                  Cabo Frio      RJ
# 15               Campo Grande      MS
# 16             Belo Horizonte      MG
# 17               Caldas Novas      GO
# 18                     Palmas      TO
# 19                      Prado      BA
# 20                    Itapema      SC
# 21        Valparaíso De Goiás      DF
# 22        Valparaíso De Goiás      DF
# 23        Valparaíso De Goiás      DF
# 24        São Pedro da Aldeia      RJ
# 25        Valparaíso De Goiás      DF
# 26                  CamaÃ§ari      BA
# 27        Valparaíso De Goiás      DF
# 28                       Mauá      SP
# 29               Porto Alegre      RS
# ...                        ...    ...
# 4970                 Itanhaém      SP
# 4971               Porto Belo      SC
# 4972                Fortaleza      CE
# 4973             Porto Alegre      RS
# 4974                Tramandaí      RS
# 4975                Guarapari      ES
# 4976             Praia Grande      SP
# 4977                 Paulista      PE
# 4978            Ilha Comprida      SP
# 4979  Jaboatão dos Guararapes      PE
# 4980                   Manaus      AM
# 4981           Capão da Canoa      RS
# 4982                 São Luís      MA
# 4983             Santo Ângelo      RS
# 4984                 Alvorada      RS
# 4985               Vila Velha      ES
# 4986                   Manaus      AM
# 4987                Indiaroba      SE
# 4988                Piraquara      PR
# 4989                 Garopaba      SC
# 16                 Restaurante em frente a puc do corel    1.0
# 17     Pontal do Lago flat - Disponível para o Carnaval    1.0
# 18                                       Casa e Kitnets    1.0
# 19              Casa para temporada Zap (73) 9 99893738    1.0
# 20                       Alugo ap em meia praia itapema    1.0
# 21    Ate 100% financiado apartamento 2 Qts Térreo c...    1.0
# 22    Ate 100% financiado apartamento 2 Qts Térreo c...    1.0
# 23    Ate 100% financiado apartamento 2 Qts Térreo c...    1.0
# 24                      Casa aluguel temporada carnaval    1.0
# 25    Ate 100% financiado apartamento 2 Qts Térreo c...    1.0
# 26                                  Aluga-se 4/4 CENTRO    1.0
# 27    Ate 100% financiado apartamento 2 Qts Térreo c...    1.0
# 28                                          Restaurante    1.0
# 29                                   Conjunto Comercial    1.0
# ...                                                 ...    ...
# 4970                                 Apto para Ano Novo  100.0
# 4971                                   Casa no interior  100.0
# 4972  Apartamento enfrente a Beira Mar, a poucos met...  100.0
# 4973                                          Temporada  100.0
# 4974      Casa na praia de Tramandaí. Ótima localização  100.0
# 4975  Oportunidade Única - Próximo ao Centro/Enseada...  100.0
# 4976  Linda Kit , precinho baratinho , temporada em ...  100.0
# 4977   Vende uma casa por traz do matadouro de paulista  100.0
# 4978                       Procuro Casa Carnaval diaria  100.0
# 4979               Apartamento Carnaval R:100,00 diária  100.0
# 4980          Alugamos ponto da SKY HDTV sem assinatura  100.0
# 4981                               Alugo capão da canoa  100.0
# 4982  Apartamento mobiliado próximo à região litorân...  100.0
# 4983                                    Casa de madeira  100.0
# 4984                                 Alugo casa Quintão  100.0
# 4985      Apartamento Temporada, em Gaivotas, 2 quartos  100.0
# 4986                          Cortinas apartir de reais  100.0
# 4987  Aluguel de casa diária ou temporada en pontal ...  100.0
# 4988  Alugo casa Praia leste Balneário Beltrame disp...  100.0
# 4989                   Férias em Garopaba até 7 pessoas  100.0
# 4990                   Aluga - se. casa na praia grande  100.0
# 4991                           Venda ê troca em,macaiba  100.0
# 4992  Apartamento a cinco minutos da praia de Cabo B...  100.0
# 4993                  Casa na estrada Guriri/Barra Nova  100.0
# 4994                    Promoção alugo praia magistério  100.0
# 4995  Casa Grande P/13 pessoas ou mais c/ Piscina e ...  100.0
# 4996                               Coworking & Business  100.0
# 4997                              Suite em jericoacoara  100.0
# 4998                                     Vendo ou troco  100.0
# 4999                                               Casa  100.0
#
# [5000 rows x 5 columns]

# %%
print(df[df['municipio']== 'Garuva '])
# Out:
#     municipio estado                                          categoria  \
# 0     Garuva      SC  Terrenos, sítios e fazendas- Anúncio Profissional
# 50    Garuva      SC  Terrenos, sítios e fazendas- Anúncio Profissional
# 496   Garuva      SC  Terrenos, sítios e fazendas- Anúncio Profissional
#
#                titulo  preco
# 0    TERRENO - Garuva    1.0
# 50   TERRENO - Garuva    1.0
# 496  TERRENO - Garuva    2.0
